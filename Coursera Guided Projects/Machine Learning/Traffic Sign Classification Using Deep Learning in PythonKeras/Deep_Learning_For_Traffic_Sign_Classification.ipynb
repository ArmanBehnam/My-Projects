# %% [markdown]
# <a href="https://colab.research.google.com/github/AymenSe/Deep-Learning-For-Traffic-Sign-Classification/blob/master/Deep_Learning_For_Traffic_Sign_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((34799, 32, 32, 3), (4410, 32, 32, 3), (12630, 32, 32, 3))

# %%
y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((34799,), (4410,), (12630,))

# %% [markdown]
# # PERFORM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 18

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 10
L_grid = 10

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (20,20))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
for i in np.arange(0, W_grid * L_grid):
    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow(X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')
    
plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray = np.sum(X_test/3, axis=3, keepdims=True)
X_valid_gray = np.sum(X_valid/3, axis=3, keepdims=True)

# %%
X_train_gray.shape, X_test_gray.shape, X_valid_gray.shape
# Out:
# ((34799, 32, 32, 1), (12630, 32, 32, 1), (4410, 32, 32, 1))

# %%
X_train_gray_norm = (X_train_gray - 128) / 128
X_test_gray_norm = (X_test_gray - 128) / 128
X_valid_gray_norm = (X_valid_gray - 128) / 128

# %%
X_train_gray_norm.max(), X_train_gray_norm.min() # all pixels now between -1 and 1
# Out:
# (0.9921875, -0.9713541666666666)

# %%
X_train_gray_norm
# Out:
# array([[[[-0.30989583],
#          [-0.51041667],
#          [-0.46354167],
#          ...,
#          [-0.28385417],
#          [-0.35677083],
#          [-0.61458333]],
#
#         [[-0.30989583],
#          [-0.5       ],
#          [-0.48177083],
#          ...,
#          [-0.3203125 ],
#          [-0.38020833],
#          [-0.59895833]],
#
#         [[-0.3203125 ],
#          [-0.48177083],
#          [-0.48697917],
#          ...,
#          [-0.34114583],
#          [-0.39583333],
#          [-0.5859375 ]],
#
#         ...,
#
#         [[-0.65364583],
#          [-0.64583333],
#          [-0.7109375 ],
#          ...,
#          [-0.56770833],
#          [-0.56770833],
#          [-0.5234375 ]],
#
#         [[-0.66666667],
#          [-0.6484375 ],
#          [-0.72395833],
#          ...,
#          [-0.59114583],
#          [-0.56770833],
#          [-0.48697917]],
#
#         [[-0.69270833],
#          [-0.6640625 ],
#          [-0.73177083],
#          ...,
#          [-0.63020833],
#          [-0.6015625 ],
#          [-0.48177083]]],
#
#
#        [[[-0.59635417],
#          [-0.59375   ],
#          [-0.6015625 ],
#          ...,
#          [-0.671875  ],
#          [-0.68229167],
#          [-0.671875  ]],
#
#         [[-0.609375  ],
#          [-0.61197917],
#          [-0.61458333],
#          ...,
#          [-0.66666667],
#          [-0.67447917],
#          [-0.671875  ]],
#
#         [[-0.62760417],
#          [-0.62239583],
#          [-0.625     ],
#          ...,
#          [-0.6640625 ],
#          [-0.671875  ],
#          [-0.671875  ]],
#
#         ...,
#
#         [[-0.72135417],
#          [-0.72916667],
#          [-0.7265625 ],
#          ...,
#          [-0.7265625 ],
#          [-0.71875   ],
#          [-0.703125  ]],
#
#         [[-0.72135417],
#          [-0.72916667],
#          [-0.7265625 ],
#          ...,
#          [-0.7265625 ],
#          [-0.71614583],
#          [-0.703125  ]],
#
#         [[-0.72135417],
#          [-0.72395833],
#          [-0.73177083],
#          ...,
#          [-0.71875   ],
#          [-0.7109375 ],
#          [-0.70833333]]],
#
#
#        [[[ 0.66145833],
#          [ 0.6640625 ],
#          [ 0.6484375 ],
#          ...,
#          [ 0.37239583],
#          [ 0.28645833],
#          [ 0.21354167]],
#
#         [[ 0.62760417],
#          [ 0.6328125 ],
#          [ 0.65104167],
#          ...,
#          [ 0.38802083],
#          [ 0.31770833],
#          [ 0.29947917]],
#
#         [[ 0.67708333],
#          [ 0.703125  ],
#          [ 0.69270833],
#          ...,
#          [ 0.29947917],
#          [ 0.22395833],
#          [ 0.30208333]],
#
#         ...,
#
#         [[-0.59895833],
#          [-0.59635417],
#          [-0.58854167],
#          ...,
#          [-0.5625    ],
#          [-0.55208333],
#          [-0.58072917]],
#
#         [[-0.57552083],
#          [-0.5859375 ],
#          [-0.578125  ],
#          ...,
#          [-0.5703125 ],
#          [-0.5703125 ],
#          [-0.57552083]],
#
#         [[-0.52864583],
#          [-0.5390625 ],
#          [-0.546875  ],
#          ...,
#          [-0.51302083],
#          [-0.5546875 ],
#          [-0.57291667]]],
#
#
#        ...,
#
#
#        [[[-0.91666667],
#          [-0.91927083],
#          [-0.921875  ],
#          ...,
#          [-0.9296875 ],
#          [-0.92447917],
#          [-0.92447917]],
#
#         [[-0.92447917],
#          [-0.92708333],
#          [-0.92447917],
#          ...,
#          [-0.92447917],
#          [-0.921875  ],
#          [-0.92447917]],
#
#         [[-0.92708333],
#          [-0.921875  ],
#          [-0.92708333],
#          ...,
#          [-0.9296875 ],
#          [-0.92708333],
#          [-0.92708333]],
#
#         ...,
#
#         [[-0.90364583],
#          [-0.90885417],
#          [-0.90104167],
#          ...,
#          [-0.92708333],
#          [-0.92447917],
#          [-0.921875  ]],
#
#         [[-0.91145833],
#          [-0.90625   ],
#          [-0.91145833],
#          ...,
#          [-0.92708333],
#          [-0.91666667],
#          [-0.91927083]],
#
#         [[-0.9140625 ],
#          [-0.92447917],
#          [-0.92447917],
#          ...,
#          [-0.91666667],
#          [-0.921875  ],
#          [-0.921875  ]]],
#
#
#        [[[ 0.34375   ],
#          [ 0.33854167],
#          [ 0.33854167],
#          ...,
#          [ 0.26302083],
#          [ 0.24479167],
#          [ 0.25260417]],
#
#         [[ 0.33333333],
#          [ 0.32291667],
#          [ 0.32291667],
#          ...,
#          [ 0.2421875 ],
#          [ 0.22916667],
#          [ 0.234375  ]],
#
#         [[ 0.34635417],
#          [ 0.31510417],
#          [ 0.3203125 ],
#          ...,
#          [ 0.234375  ],
#          [ 0.23958333],
#          [ 0.234375  ]],
#
#         ...,
#
#         [[ 0.15885417],
#          [ 0.15885417],
#          [ 0.15625   ],
#          ...,
#          [ 0.10416667],
#          [ 0.09895833],
#          [ 0.09895833]],
#
#         [[ 0.15104167],
#          [ 0.1484375 ],
#          [ 0.15364583],
#          ...,
#          [ 0.078125  ],
#          [ 0.09895833],
#          [ 0.09895833]],
#
#         [[ 0.1484375 ],
#          [ 0.140625  ],
#          [ 0.14583333],
#          ...,
#          [ 0.07552083],
#          [ 0.0859375 ],
#          [ 0.09895833]]],
#
#
#        [[[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.98958333],
#          ...,
#          [-0.3515625 ],
#          [-0.35416667],
#          [-0.55208333]],
#
#         [[ 0.98958333],
#          [ 0.9921875 ],
#          [ 0.953125  ],
#          ...,
#          [-0.35416667],
#          [-0.26041667],
#          [-0.4921875 ]],
#
#         [[ 0.96354167],
#          [ 0.98177083],
#          [ 0.83333333],
#          ...,
#          [-0.29166667],
#          [-0.36197917],
#          [-0.55729167]],
#
#         ...,
#
#         [[-0.546875  ],
#          [-0.55989583],
#          [-0.5859375 ],
#          ...,
#          [-0.63020833],
#          [-0.15364583],
#          [-0.36979167]],
#
#         [[-0.26041667],
#          [-0.515625  ],
#          [-0.57552083],
#          ...,
#          [-0.56510417],
#          [-0.10416667],
#          [-0.2578125 ]],
#
#         [[ 0.578125  ],
#          [-0.0546875 ],
#          [-0.50260417],
#          ...,
#          [-0.65104167],
#          [-0.3515625 ],
#          [-0.37760417]]]])

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5, 5), activation = 'relu', input_shape = (32, 32, 1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Dropout(0.2))

CNN.add(layers.Conv2D(16, (5, 5), activation = 'relu'))
CNN.add(layers.AveragePooling2D())


CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation = 'relu'))
CNN.add(layers.Dense(84, activation = 'relu'))

CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(X_train_gray_norm,
                  y_train,
                  batch_size = 500,
                  epochs = 50,
                  verbose = 1,
                  validation_data = (X_valid_gray_norm, y_valid))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 23s 653us/sample - loss: 0.6007 - accuracy: 0.8259 - val_loss: 0.7291 - val_accuracy: 0.8050
# Epoch 2/50
# 34799/34799 [==============================] - 23s 647us/sample - loss: 0.5188 - accuracy: 0.8510 - val_loss: 0.6610 - val_accuracy: 0.8186
# Epoch 3/50
# 34799/34799 [==============================] - 23s 647us/sample - loss: 0.4503 - accuracy: 0.8727 - val_loss: 0.6318 - val_accuracy: 0.8424
# Epoch 4/50
# 34799/34799 [==============================] - 23s 671us/sample - loss: 0.4086 - accuracy: 0.8842 - val_loss: 0.6314 - val_accuracy: 0.8324
# Epoch 5/50
# 34799/34799 [==============================] - 23s 654us/sample - loss: 0.3662 - accuracy: 0.8967 - val_loss: 0.5646 - val_accuracy: 0.8558
# Epoch 6/50
# 34799/34799 [==============================] - 23s 659us/sample - loss: 0.3354 - accuracy: 0.9074 - val_loss: 0.5675 - val_accuracy: 0.8546
# Epoch 7/50
# 34799/34799 [==============================] - 23s 658us/sample - loss: 0.3039 - accuracy: 0.9141 - val_loss: 0.5390 - val_accuracy: 0.8601
# Epoch 8/50
# 34799/34799 [==============================] - 23s 657us/sample - loss: 0.2786 - accuracy: 0.9217 - val_loss: 0.5476 - val_accuracy: 0.8512
# Epoch 9/50
# 34799/34799 [==============================] - 23s 675us/sample - loss: 0.2542 - accuracy: 0.9289 - val_loss: 0.4713 - val_accuracy: 0.8812
# Epoch 10/50
# 34799/34799 [==============================] - 23s 666us/sample - loss: 0.2350 - accuracy: 0.9341 - val_loss: 0.4770 - val_accuracy: 0.8780
# Epoch 11/50
# 34799/34799 [==============================] - 23s 659us/sample - loss: 0.2168 - accuracy: 0.9392 - val_loss: 0.4875 - val_accuracy: 0.8855
# Epoch 12/50
# 34799/34799 [==============================] - 23s 658us/sample - loss: 0.2007 - accuracy: 0.9446 - val_loss: 0.4510 - val_accuracy: 0.8816
# Epoch 13/50
# 34799/34799 [==============================] - 23s 656us/sample - loss: 0.1852 - accuracy: 0.9488 - val_loss: 0.4232 - val_accuracy: 0.8971
# Epoch 14/50
# 34799/34799 [==============================] - 24s 677us/sample - loss: 0.1797 - accuracy: 0.9491 - val_loss: 0.4723 - val_accuracy: 0.8814
# Epoch 15/50
# 34799/34799 [==============================] - 23s 663us/sample - loss: 0.1672 - accuracy: 0.9530 - val_loss: 0.4616 - val_accuracy: 0.8896
# Epoch 16/50
# 34799/34799 [==============================] - 23s 659us/sample - loss: 0.1535 - accuracy: 0.9571 - val_loss: 0.4571 - val_accuracy: 0.8955
# Epoch 17/50
# 34799/34799 [==============================] - 23s 660us/sample - loss: 0.1472 - accuracy: 0.9587 - val_loss: 0.4809 - val_accuracy: 0.8873
# Epoch 18/50
# 34799/34799 [==============================] - 23s 664us/sample - loss: 0.1413 - accuracy: 0.9597 - val_loss: 0.4433 - val_accuracy: 0.8937
# Epoch 19/50
# 34799/34799 [==============================] - 23s 674us/sample - loss: 0.1304 - accuracy: 0.9622 - val_loss: 0.4440 - val_accuracy: 0.8982
# Epoch 20/50
# 34799/34799 [==============================] - 23s 662us/sample - loss: 0.1234 - accuracy: 0.9645 - val_loss: 0.4075 - val_accuracy: 0.9066
# Epoch 21/50
# 34799/34799 [==============================] - 23s 661us/sample - loss: 0.1145 - accuracy: 0.9679 - val_loss: 0.4113 - val_accuracy: 0.8991
# Epoch 22/50
# 34799/34799 [==============================] - 23s 659us/sample - loss: 0.1091 - accuracy: 0.9700 - val_loss: 0.4295 - val_accuracy: 0.8982
# Epoch 23/50
# 34799/34799 [==============================] - 23s 663us/sample - loss: 0.1088 - accuracy: 0.9691 - val_loss: 0.4292 - val_accuracy: 0.8998
# Epoch 24/50
# 34799/34799 [==============================] - 23s 657us/sample - loss: 0.0993 - accuracy: 0.9715 - val_loss: 0.4169 - val_accuracy: 0.9045
# Epoch 25/50
# 34799/34799 [==============================] - 24s 676us/sample - loss: 0.0922 - accuracy: 0.9729 - val_loss: 0.4593 - val_accuracy: 0.8959
# Epoch 26/50
# 34799/34799 [==============================] - 23s 665us/sample - loss: 0.0938 - accuracy: 0.9727 - val_loss: 0.4263 - val_accuracy: 0.8918
# Epoch 27/50
# 34799/34799 [==============================] - 23s 665us/sample - loss: 0.0862 - accuracy: 0.9747 - val_loss: 0.4341 - val_accuracy: 0.9009
# Epoch 28/50
# 34799/34799 [==============================] - 23s 659us/sample - loss: 0.0833 - accuracy: 0.9751 - val_loss: 0.4352 - val_accuracy: 0.9052
# Epoch 29/50
# 34799/34799 [==============================] - 23s 666us/sample - loss: 0.0787 - accuracy: 0.9778 - val_loss: 0.4475 - val_accuracy: 0.9002
# Epoch 30/50
# 34799/34799 [==============================] - 24s 679us/sample - loss: 0.0750 - accuracy: 0.9784 - val_loss: 0.4617 - val_accuracy: 0.9020
# Epoch 31/50
# 34799/34799 [==============================] - 23s 662us/sample - loss: 0.0724 - accuracy: 0.9794 - val_loss: 0.3863 - val_accuracy: 0.9104
# Epoch 32/50
# 34799/34799 [==============================] - 23s 664us/sample - loss: 0.0729 - accuracy: 0.9795 - val_loss: 0.4833 - val_accuracy: 0.8957
# Epoch 33/50
# 34799/34799 [==============================] - 23s 664us/sample - loss: 0.0641 - accuracy: 0.9813 - val_loss: 0.4747 - val_accuracy: 0.8980
# Epoch 34/50
# 34799/34799 [==============================] - 23s 667us/sample - loss: 0.0683 - accuracy: 0.9791 - val_loss: 0.4250 - val_accuracy: 0.9009
# Epoch 35/50
# 34799/34799 [==============================] - 24s 685us/sample - loss: 0.0602 - accuracy: 0.9832 - val_loss: 0.4235 - val_accuracy: 0.9100
# Epoch 36/50
# 34799/34799 [==============================] - 23s 663us/sample - loss: 0.0630 - accuracy: 0.9814 - val_loss: 0.4472 - val_accuracy: 0.9027
# Epoch 37/50
# 34799/34799 [==============================] - 24s 678us/sample - loss: 0.0624 - accuracy: 0.9814 - val_loss: 0.4321 - val_accuracy: 0.9068
# Epoch 38/50
# 34799/34799 [==============================] - 23s 670us/sample - loss: 0.0560 - accuracy: 0.9830 - val_loss: 0.4323 - val_accuracy: 0.9045
# Epoch 39/50
# 34799/34799 [==============================] - 23s 664us/sample - loss: 0.0543 - accuracy: 0.9834 - val_loss: 0.3990 - val_accuracy: 0.9145
# Epoch 40/50
# 34799/34799 [==============================] - 24s 681us/sample - loss: 0.0517 - accuracy: 0.9854 - val_loss: 0.4579 - val_accuracy: 0.9063
# Epoch 41/50
# 34799/34799 [==============================] - 23s 666us/sample - loss: 0.0463 - accuracy: 0.9865 - val_loss: 0.4995 - val_accuracy: 0.9020
# Epoch 42/50
# 34799/34799 [==============================] - 23s 667us/sample - loss: 0.0569 - accuracy: 0.9831 - val_loss: 0.4885 - val_accuracy: 0.9050
# Epoch 43/50
# 34799/34799 [==============================] - 23s 663us/sample - loss: 0.0504 - accuracy: 0.9852 - val_loss: 0.4192 - val_accuracy: 0.9132
# Epoch 44/50
# 34799/34799 [==============================] - 24s 687us/sample - loss: 0.0441 - accuracy: 0.9870 - val_loss: 0.4423 - val_accuracy: 0.9095
# Epoch 45/50
# 34799/34799 [==============================] - 23s 673us/sample - loss: 0.0423 - accuracy: 0.9877 - val_loss: 0.4668 - val_accuracy: 0.9052
# Epoch 46/50
# 34799/34799 [==============================] - 23s 663us/sample - loss: 0.0452 - accuracy: 0.9866 - val_loss: 0.4488 - val_accuracy: 0.9150
# Epoch 47/50
# 34799/34799 [==============================] - 23s 662us/sample - loss: 0.0492 - accuracy: 0.9852 - val_loss: 0.4817 - val_accuracy: 0.9045
# Epoch 48/50
# 34799/34799 [==============================] - 23s 658us/sample - loss: 0.0420 - accuracy: 0.9876 - val_loss: 0.4385 - val_accuracy: 0.9159
# Epoch 49/50
# 34799/34799 [==============================] - 23s 672us/sample - loss: 0.0422 - accuracy: 0.9876 - val_loss: 0.3891 - val_accuracy: 0.9240
# Epoch 50/50
# 34799/34799 [==============================] - 24s 676us/sample - loss: 0.0394 - accuracy: 0.9884 - val_loss: 0.4494 - val_accuracy: 0.9116

# %% [markdown]
# # ASSESS TRAINED CNN MODEL PERFORMANCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 12630/12630 [==============================] - 5s 428us/sample - loss: 0.7732 - accuracy: 0.9029
# Test Accuracy: 0.9029295444488525

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))
plt.plot(epochs, loss, 'ro', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'ro', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label = 'validation Accuracy')
plt.title('Accuracy and Validation accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy and Validation accuracy')

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # APPENDIX

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
